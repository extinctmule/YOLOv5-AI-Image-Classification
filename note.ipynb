# %% [markdown]
# yolov5 공식 깃헙에 보면 루트 디렉토리에 val.py와 detect.py와 train.py export.py 등등 여러 파일이 있는데
# detect.py의 간단한 기능만 기반으로 필요없는 것을 빼고 라이브러리 등 상충되는 기능을 제거한 후 cv2.imread를 인풋으로 받도록 남겨야 하는데, github에 runtime stack이라는 식으로 나온 simplified yolov5 버전들이 올라와있습니다.
# 문제는 yolo는 py파일들이
#
# 제일 알려진 yolov5-rt-stack
# https://github.com/zhiqwang/yolov5-rt-stack
# 같은 경우 yolov5x를 지원하지 않아서 저는 다른 코드
# https://github.com/amirhosseinh77/JetsonYolo
#  를 기반으로 코드를 변경해갔는데 No module named 'utils' 에러 등을 계속 해결하지 못했습니다.
